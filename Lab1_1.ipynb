# %% [markdown]
# <a href="https://colab.research.google.com/github/rishi12jn/Deep-Learning-Lab/blob/main/Lab1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('Copy of Height Weight Data.csv')

# %%
print(data.describe())
# Out:
#               Index  Height(Inches)  Weight(Pounds)
# count  25000.000000    25000.000000    25000.000000
# mean   12500.500000       67.993114      127.079421
# std     7217.022701        1.901679       11.660898
# min        1.000000       60.278360       78.014760
# 25%     6250.750000       66.704397      119.308675
# 50%    12500.500000       67.995700      127.157750
# 75%    18750.250000       69.272958      134.892850
# max    25000.000000       75.152800      170.924000

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
ls
# Out:
# 'Copy of Height Weight Data.csv'   Untitled0.ipynb

# %%
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage import data
from skimage.filters import sobel
image = imread('/content/drive/MyDrive/Colab Notebooks/Names-of-Wild-Animals-For-Preschoolers-and-Kids-In-English-696x476.jpg', as_gray=True)
sobel_image = sobel(image)
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

ax[0].imshow(image, cmap='gray')
ax[0].set_title('Original Image')
ax[0].axis('off')

ax[1].imshow(sobel_image, cmap='gray')
ax[1].set_title('Sobel Filtered Image')
ax[1].axis('off')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.morphology import disk
from skimage.filters import rank

image = imread('/content/drive/MyDrive/Colab Notebooks/Names-of-Wild-Animals-For-Preschoolers-and-Kids-In-English-696x476.jpg', as_gray=True)

footprint = disk(20)

percentile_result = rank.mean_percentile(image, footprint=footprint, p0=0.1, p1=0.9)
bilateral_result = rank.mean_bilateral(image, footprint=footprint, s0=500, s1=500)
normal_result = rank.mean(image, footprint=footprint)

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10), sharex=True, sharey=True)
ax = axes.ravel()

titles = ['Original', 'Percentile mean', 'Bilateral mean', 'Local mean']
imgs = [image, percentile_result, bilateral_result, normal_result]
for n in range(len(imgs)):
    ax[n].imshow(imgs[n], cmap=plt.cm.gray)
    ax[n].set_title(titles[n])
    ax[n].axis('off')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3553: UserWarning: Possible precision loss converting image of type float64 to uint8 as required by rank filters. Convert manually using skimage.util.img_as_ubyte to silence this warning.
#   exec(code_obj, self.user_global_ns, self.user_ns)
